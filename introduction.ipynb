# %% [markdown]
# # Introduction
#
# This Kernel uses python to showcase some simple things. In Gitlab, no plots will be shown, so maybe.. just follow the procedure below to investigate the contents of the notebook.
#
# ## Beware
#
# If you want to be able to interfere with any of those cells, not just looking at the rendered cells, you need to start jupyter locally. First, get and clone this repository. Then move via console to this location, and start the notebook server with **jupyter notebook**. It is possible, that you need to install **jupyter** with a simple "sudo apt-get install jupyter". When done, you will be presented with a list of all files in the current directory. Open the **introduction.ipynb** and you should see a notebook with which you can fully interfere. For all examples to run as intended, make sure you have all dependencies installed. The python applied here, as it would be the case when applied on your console, might require some packages, for instance numpy and matplotlib installed. To make sure use: "sudo apt-get install python-numpy python-matplotlib" ;)
#
#
# ### First some tips:
#
# The document is organized in cells (The thing enclosed in a rectangle here.). To edit a cell ("edit-mode"), just hit enter when its selected or double click it. To leave the cell and navigate around, hit "ESC" ("command-mode"). To render or execute the contents of a cell, hit ctrl+shift. For anything else, hit ctrl+shift+p, and type whatever you want to do, the command will pop up soon and it helps a lot to remember important keyboard shortcuts. Many commands are also accessible with the menu above.
#
# ## Simple Interaction
#
# You may want to try a simple case: hit ctrl+shift+p and type "insert cell". You will see two commands, one to add one above of the current cell and one below. For both you need to be in "command-mode" and hit either "A" or "B" afterwards. lets try this now!

# %%
#Inserting a new cell usually provides you with a new code cell.

# %% [markdown]
# To change the type of the cell, change to command-mode and hit "M", or just use the dropdown on top.

# %% [markdown]
# The following cell includes numpy to get the random data, matplotlib pyplot to plot it, and uses the magic line matplotlib notebook to set up internal plotting (with this line, all plots are plotted in here.)
#
# With shift+ctrl we execute the current cell. try it. if you see the number in brackets of "In" change, you succeeded.

# %%
import numpy as np
import matplotlib.pyplot as plt


# %matplotlib inline

# %% [markdown]
# ## Now for the goodies:
#
# ### let's create a random array and display it.
#
# Now lets create some data:

# %%
data = np.random.random((400,600))

# %% [markdown]
# ... and plot it:

# %%
plt.figure()
plt.imshow(data)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# As you can see, we're provided with a neat figure, with which we can interact. Different cells can use code that has already been processed, so lets try to get data from above and filter it with a gaussian:
# (To suppress unuseful output, as above (the matplotlib thingy), add semicolons as in the example below)

# %%
from scipy.ndimage.filters import gaussian_filter
data = gaussian_filter(data,5)
plt.figure()
plt.imshow(data);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# If we now recalculate the cell that generated our plot above, we can see that the data is now gaussian filtered. The history of commands follows the numbers shown besides "In". But be careful, also previous and now deleted cells calculations influence the ones that are displayed, to be sure, a complete recalculation of the notebook can help to make sure of its integrity. You can do this with "restart and run cells" in "kernel" in the menu.
#
# Oh, did I mention latex is supported as well? Use dollar or double dollar signs to start a inline or full math environment in $\LaTeX$
#
# $$ A = \int\limits_0^\infty F(x)$$
